# %% [markdown]
# <a href="https://colab.research.google.com/github/sourabhumarani/CDAP-Python-Superstore-Data/blob/main/Sourabh_Umarani_Python_Assignment_20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing required libraries

import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
my_dataset = '/content/supermarket_sales.csv - supermarket_sales.csv.csv'
df = pd.read_csv(my_dataset)

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity        Date   Time  \
# 0       Health and beauty       74.69       7.0  01-05-2019  13:08
# 1  Electronic accessories       15.28       5.0  02-05-2019  10:29
# 2      Home and lifestyle       46.33       7.0  03-05-2019  13:23
# 3       Health and beauty       58.22       8.0  04-05-2019  20:33
# 4       Sports and travel       86.31       7.0  05-05-2019  10:37
#
#        Payment  gross profit  Rating
# 0      Ewallet       26.1415     9.1
# 1         Cash        3.8200     9.6
# 2  Credit card       16.2155     7.4
# 3      Ewallet       23.2880     8.4
# 4      Ewallet       30.2085     5.3

# %%
print(df.shape)
# Out:
# (1000, 13)

# %%
df.head(10)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
# 5  699-14-3026      C  Naypyitaw        Normal     NaN
# 6  355-53-5943      A     Yangon        Member  Female
# 7  315-22-5665      C  Naypyitaw        Normal  Female
# 8  665-32-9167      A     Yangon        Member  Female
# 9  692-92-5582      B   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity        Date   Time  \
# 0       Health and beauty       74.69       7.0  01-05-2019  13:08
# 1  Electronic accessories       15.28       5.0  02-05-2019  10:29
# 2      Home and lifestyle       46.33       7.0  03-05-2019  13:23
# 3       Health and beauty       58.22       8.0  04-05-2019  20:33
# ...

# %%
df.tail(10)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 990  886-18-2897      A     Yangon        Normal  Female
# 991  602-16-6955      B   Mandalay        Normal  Female
# 992  745-74-0715      A     Yangon        Normal    Male
# 993  690-01-6631      B   Mandalay        Normal    Male
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity        Date   Time  \
# 990      Food and beverages       56.56       5.0  15-01-2022  19:06
# 991       Sports and travel       76.60      10.0  16-01-2022  18:10
# 992  Electronic accessories       58.03       2.0  17-01-2022  20:46
# ...

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Date', 'Time', 'Payment',
#        'gross profit', 'Rating'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Unit price    Quantity  gross profit      Rating
# count  984.000000  993.000000   1000.000000  1000.00000
# mean    55.776118    5.502518     15.379369     6.97270
# std     26.507807    2.927595     11.708825     1.71858
# min     10.080000    1.000000      0.508500     4.00000
# 25%     33.125000    3.000000      5.924875     5.50000
# 50%     55.475000    5.000000     12.088000     7.00000
# 75%     77.980000    8.000000     22.445250     8.50000
# max     99.960000   10.000000     49.650000    10.00000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Invoice ID     1000 non-null   object
#  1   Branch         1000 non-null   object
#  2   City           1000 non-null   object
#  3   Customer type  1000 non-null   object
#  4   Gender         990 non-null    object
#  5   Product line   1000 non-null   object
#  6   Unit price     984 non-null    float64
#  7   Quantity       993 non-null    float64
#  8   Date           1000 non-null   object
#  9   Time           1000 non-null   object
#  10  Payment        993 non-null    object
#  11  gross profit   1000 non-null   float64
#  12  Rating         1000 non-null   float64
# dtypes: float64(4), object(9)
# memory usage: 101.7+ KB

# %%
df.isnull().sum().sort_values(ascending = False)[:10]
# Out:
# Unit price       16
# Gender           10
# Quantity          7
# Payment           7
# Invoice ID        0
# Branch            0
# City              0
# Customer type     0
# Product line      0
# Date              0
# dtype: int64
